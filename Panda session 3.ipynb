# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv('Universities.csv')

# %%
df1
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0          Brown  1310     89      22       13     22704        94
# 1        CalTech  1415    100      25        6     63575        81
# 2            CMU  1260     62      59        9     25026        72
# 3       Columbia  1310     76      24       12     31510        88
# 4        Cornell  1280     83      33       13     21864        90
# 5      Dartmouth  1340     89      23       10     32162        95
# 6           Duke  1315     90      30       12     31585        95
# 7     Georgetown  1255     74      24       12     20126        92
# 8        Harvard  1400     91      14       11     39525        97
# 9   JohnsHopkins  1305     75      44        7     58691        87
# 10           MIT  1380     94      30       10     34870        91
# 11  Northwestern  1260     85      39       11     28052        89
# 12     NotreDame  1255     81      42       13     15122        94
# ...

# %%
plt.hist(df1['SAT'])
# Out:
# (array([1., 3., 0., 0., 1., 2., 7., 4., 2., 5.]),
#  array([1005., 1046., 1087., 1128., 1169., 1210., 1251., 1292., 1333.,
#         1374., 1415.]),
#  <BarContainer object of 10 artists>)

# %%
plt.show()

# %%
plt.hist(df1['Accept'])
# Out:
# (array([4., 5., 4., 5., 1., 2., 1., 2., 0., 1.]),
#  array([14. , 21.6, 29.2, 36.8, 44.4, 52. , 59.6, 67.2, 74.8, 82.4, 90. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4604\3956861296.py in <module>
# ----> 1 sn.histplot(df1['SAT'])
#
# NameError: name 'sn' is not defined

# %%
sns.histplot(df1['SAT'])
# Out:
# <AxesSubplot:xlabel='SAT', ylabel='Count'>

# %%
sns.scatterplot(x='SAT',y='Accept',data=df1)
# Out:
# <AxesSubplot:xlabel='SAT', ylabel='Accept'>

# %%
sns.pairplot(df1.iloc[:,1:])

# %%
sns.pairplot(df1)

# %%
sns.pairplot(df1.iloc[:,2:])

# %%
plt.boxplot(df1['SAT'])
plt.xlabel('SATscore')
plt.ylabel('Values')
plt.title('Boxplot of SAT')
plt.show()

# %%
plt.boxplot(df1['SAT'], vert = False)
plt.xlabel('SATscore')
plt.ylabel('Values')
plt.title('Boxplot of SAT')
plt.show()

# %%
plt.boxplot(df1['SAT'], vert = True)
plt.xlabel('SATscore')
plt.ylabel('Values')
plt.title('Boxplot of SAT')
plt.show()

# %%
df = pd.read_csv('Universities.csv')
df
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0          Brown  1310     89      22       13     22704        94
# 1        CalTech  1415    100      25        6     63575        81
# 2            CMU  1260     62      59        9     25026        72
# 3       Columbia  1310     76      24       12     31510        88
# 4        Cornell  1280     83      33       13     21864        90
# 5      Dartmouth  1340     89      23       10     32162        95
# 6           Duke  1315     90      30       12     31585        95
# 7     Georgetown  1255     74      24       12     20126        92
# 8        Harvard  1400     91      14       11     39525        97
# 9   JohnsHopkins  1305     75      44        7     58691        87
# 10           MIT  1380     94      30       10     34870        91
# 11  Northwestern  1260     85      39       11     28052        89
# 12     NotreDame  1255     81      42       13     15122        94
# ...

# %%
plt.boxplot(df1['Accept'], vert = True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2879f9128b0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2879f912280>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2879f9124c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x2879f91f370>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2879f91f520>],
#  'means': []}

# %%
sns.distplot(df['SAT'])
# Out:
# <AxesSubplot:xlabel='SAT', ylabel='Density'>

# %%
plt.plot(df['SAT'],df['Top10'],'rs')
plt.xlabel('SAT')
plt.ylabel('Top10')
plt.title('SAT vs Top10')
# Out:
# Text(0.5, 1.0, 'SAT vs Top10')

# %%
pd.set_option('display.min_rows',None)
